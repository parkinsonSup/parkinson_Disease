# %% [markdown]
# <br>
# <br>
# <h2 style = "font-family: garamond; font-size: 40px; font-style: normal; letter-spcaing: 3px; background-color:#1DA1F2 ; color :#FFFFFF; border-radius: 5px 5px; padding:10px;text-align:center; font-weight: bold">Let's Detect Parkinson's Disease using Data Science </h2>
# <br>
# <br>
#
# <div class="Column">
#   <div class="row">
#     <img src="https://images.everydayhealth.com/images/neurology/parkinsons-disease/recognizing-the-progression-of-parkinsons-722x406.jpg" alt="Snow" style="width:100%">
#   </div>

# %% [markdown]
# <font size="3"><font style="font-family:Georgia">Parkinson's is a neurodegenarative progressive disorder disease. It affects the nervous system and the part of the body controlled by it. It appears in the part of the brain called substantia nigra. Normally these brain cells produce dopamine and these dopamine operates in a delicate balance with other neurotransmitters to help cordinate the millions of nerve and muscle cell involved in the movement. When these nerve cells die or become impaired, they lose the ability to produce the dopamine. When 60-80% of these cells are lost then enough dopamine are not produced and Parkinson's motor symptoms appear. Without enough dopamine, this balance is disrupted resulting tremor, rigidity, slowness of movement and impaired balance. So Parkinson's disease is caused by the disruption of the brain cells that produce the dopamine which allows the brain to communicate each other and control the fluency of the movement. It is thought that the disease begins many years before the motor symptoms appears and therefore, researchers are looking for ways to recognize the non-motor symptoms that appear early in the disease as early as possible, thereby halting the progression of the disease. A person suffering from the Parkinson's can have following symptoms:<font>
#
# * <font size='2'><font style="font-family:Georgia"><strong>*Tremor*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Slowed movement*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Rigid muscle*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Impaired posture*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Loss of automatic movement*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Speech change*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Writing change*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Impaired posture*</strong></font>
#
# <font size='3'><font style="font-family:Georgia">Also, Parkinson's disease can have other symptoms that include:</font>
#
# * <font size='2'><font style="font-family:Georgia"><strong>*Depression*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Anxiety*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Sleeping and memory-related issues*</strong></font>
# * <font size='2'><font style="font-family:Georgia"><strong>*Loss of sense of smell along with balance problems*</strong></font>
#
# <font size='3'><font style="font-family:Georgia">The symptoms of Parkinson's disease can be different from patient to pateint. Early sign of the disease can be mild and can go unnoticed. Symptoms often begin on one side of your body and usually remain worse on that side. Sometimes it is difficult to detect whether there is Parkinson's disease present in the patient's body. Parkinson's disease if detected in the early stage will be curable, and will be time and cost effective, but there is no effective treatment in the advanced stage.</font>
#
# <font size='3'><font style="font-family:Georgia"> The dataset used in this project is from <a href="https://www.kaggle.com/datasets/vikasukani/parkinsons-disease-data-set"><strong>Kaggle data bank</strong></a>. The dataset has 24 columns, thus we need to reduce the dimension before we train the data. The target or independent variable is "status" with binary values of 0 and 1. Status values for healthy person and PD person are 0 and 1 respectively. This is a classification probelm. The goal of this project is to develope the best machine learning model to predict the Parkinson's disease so that we can treat the patient in the timely manner. The following are the columns in the dataset.</font>
#
#
# * <font size='3'><font style="font-family:Georgia"><strong>*name* - </strong>ASCII <font size='3'>subject name and recording number</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:Fo(Hz)* - </strong><font size='3'>Average vocal fundamental frequency</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:Fhi(Hz)* - </strong><font size='3'>Maximum vocal fundamental frequency </font>
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:Flo(Hz)* - </strong><font size='3'>Minimum vocal fundamental frequency </font>
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:Jitter(%)*</strong>,
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:Jitter(Abs)*</strong>,
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:RAP*</strong>,
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:PPQ*</strong>,
# * <font size='2'><font style="font-family:Georgia"><strong>*Jitter:DDP* - </strong><font size='3'>Several measures of variation in fundamental frequency</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:Shimmer*</strong></font>,
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:Shimmer(dB)*</strong></font>,
# * <font size='2'><font style="font-family:Georgia"><strong>*Shimmer:APQ3*</strong></font>,
# * <font size='2'><font style="font-family:Georgia"><strong>*Shimmer:APQ5*</strong></font>,
# * <font size='2'><font style="font-family:Georgia"><strong>*MDVP:APQ*</strong></font>,
# * <font size='2'><font style="font-family:Georgia"><strong>*Shimmer:DDA -* </strong><font size='3'>Several measures of variation in amplitude</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*NHR*</strong>,
# * <font size='2'><font style="font-family:Georgia"><strong>*HNR -* </strong><font size='3'>Two measures of ratio of noise to tonal components in the voice</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*status -* </strong><font size='3'>Health status of the subject (one) - Parkinson's, (zero) - healthy</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*RPDE*</strong></font>,
# *<font size='2'><font style="font-family:Georgia"><strong>*D2 -*</strong><font size='3'>Two nonlinear dynamical complexity measures</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*DFA -* </strong><font size='3'>Signal fractal scaling exponent</font>
# * <font size='2'><font style="font-family:Georgia"><strong>*spread1,spread2,PPE -* </strong><font size='3'>Three nonlinear measures of fundamental frequency variation</font>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score, classification_report

from xgboost import XGBClassifier

# %%
import os
for dirname, _, filenames in os.walk('D:/팀 프로젝트/parkinsons.data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %% [markdown]
# # Read the data

# %%
#  let’s read the data into a DataFrame 

#Read the data
df=pd.read_csv('D:/팀 프로젝트/parkinsons.data')
print(df.shape,'\n')
df.head()
# Out:
# (195, 24)
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
# descrive the data

df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
#  To know how many rows and cols and NA values

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
#  16  HNR               195 non-null    float64
#  17  status            195 non-null    int64
#  18  RPDE              195 non-null    float64
#  19  DFA               195 non-null    float64
#  20  spread1           195 non-null    float64
#  21  spread2           195 non-null    float64
#  22  D2                195 non-null    float64
#  23  PPE               195 non-null    float64
# dtypes: float64(22), int64(1), object(1)
# memory usage: 36.7+ KB

# %%
#  shape of the dataset 

df.shape
# Out:
# (195, 24)

# %%
#Get the features and labels
#독립변수(X)와 종속변수(y)를 분리하는 작업
X_un=df.copy()
X_un=X_un.drop(['name','status'],axis=1) #df의 특정 행 또는 열 제거하는 메서드(X_un.drop)로 열 제거(axis=1)
y_un=df[['status']] #y_un에 종속변수 'status'열의 데이터 저장

# %%
#0 is healthy 1 is parkison affected
y_un.value_counts() #y_un에 있는 각 고유값의 개수를 셈
# Out:
# status
# 1         147
# 0          48
# Name: count, dtype: int64

# %%
#df 'status'열에 있는 값들의 분포
#.plot(kind='pie', autopct = "%1.0f%%") → value_counts()결과를 파이그래프로 시각화

df['status'].value_counts().plot(kind='pie', autopct = "%1.0f%%")
# Out:
# <Axes: ylabel='count'>

# %%
#박스플롯그래프는 데이터의 분포와 이상치를 시각적으로 파악하는데 매우 용이

X_un.boxplot(figsize=(15,7))
# Out:
# <Axes: >

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=3,test_size=0.2,random_state=24)

for train_index,test_index in split.split(X_un,y_un):
    strat_train_set_x,strat_train_y=X_un.loc[train_index],y_un.loc[train_index]
    strat_test_set_x,strat_test_y=X_un.loc[test_index],y_un.loc[test_index] #completely unseen to our classifier

# %%
print(strat_train_set_x.shape,strat_train_y.shape)   
print(strat_test_set_x.shape,strat_test_y.shape)
# Out:
# (156, 22) (156, 1)
# (39, 22) (39, 1)

# %% [markdown]
# # without cross validation and without scaling

# %%
#Train the model
from sklearn.metrics import precision_score, accuracy_score,recall_score
model=XGBClassifier(use_label_encoder=False,eval_metric='rmse')
model.fit(strat_train_set_x,strat_train_y)
y_pred=model.predict(strat_test_set_x)

print('accuracy score %.2f'% accuracy_score(y_pred,strat_test_y))
print('recall score %.2f'%recall_score(y_pred,strat_test_y))
# Out:
# accuracy score 0.97
# recall score 0.97
# c:\Users\asia\.conda\envs\p39tf2\lib\site-packages\xgboost\core.py:158: UserWarning: [11:47:29] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-08cbc0333d8d4aae1-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %%
print("Confusion Matrix: ")
cf_matrix=confusion_matrix(y_pred,strat_test_y)

print("\nClassification Report:")
print(classification_report(y_pred,strat_test_y))
# Out:
# Confusion Matrix:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95         9
#            1       1.00      0.97      0.98        30
#
#     accuracy                           0.97        39
#    macro avg       0.95      0.98      0.97        39
# weighted avg       0.98      0.97      0.97        39

# %%
print("Confusion Matrix: ")
cf_matrix=confusion_matrix(y_pred,strat_test_y)

print("\nClassification Report:")
print(classification_report(y_pred,strat_test_y))


import seaborn as sns
sns.heatmap(cf_matrix, annot=True)
# Out:
# Confusion Matrix:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.90      1.00      0.95         9
#            1       1.00      0.97      0.98        30
#
#     accuracy                           0.97        39
#    macro avg       0.95      0.98      0.97        39
# weighted avg       0.98      0.97      0.97        39
# <Axes: >

# %% [markdown]
# # Using ANN

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow_addons as tfa
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
# Out:
# c:\Users\asia\.conda\envs\p39tf2\lib\site-packages\tensorflow_addons\utils\tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# # Set Configurations and read data

# %%
SEED = 42
EPOCHS = 300
BATCH_SIZE = 32

df = pd.read_csv('D:/팀 프로젝트/parkinsons.data')

# %%
def seed_everything(seed):
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    tf.random.set_seed(seed)

seed_everything(SEED)

# %% [markdown]
# # EDA

# %%
df['status'].value_counts()
# Out:
# status
# 1    147
# 0     48
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# 25%            0.000020    0.001660    0.001860    0.004985      0.016505
# 50%            0.000030    0.002500    0.002690    0.007490      0.022970
# 75%            0.000060    0.003835    0.003955    0.011505      0.037885
# max            0.000260    0.021440    0.019580    0.064330      0.119080
#
#        MDVP:Shimmer(dB)  ...  Shimmer:DDA         NHR         HNR      status  \
# count        195.000000  ...   195.000000  195.000000  195.000000  195.000000
# mean           0.282251  ...     0.046993    0.024847   21.885974    0.753846
# std            0.194877  ...     0.030459    0.040418    4.425764    0.431878
# min            0.085000  ...     0.013640    0.000650    8.441000    0.000000
# 25%            0.148500  ...     0.024735    0.005925   19.198000    1.000000
# 50%            0.221000  ...     0.038360    0.011660   22.085000    1.000000
# 75%            0.350000  ...     0.060795    0.025640   25.075500    1.000000
# max            1.302000  ...     0.169420    0.314820   33.047000    1.000000
#
#              RPDE         DFA     spread1     spread2          D2         PPE
# count  195.000000  195.000000  195.000000  195.000000  195.000000  195.000000
# mean     0.498536    0.718099   -5.684397    0.226510    2.381826    0.206552
# std      0.103942    0.055336    1.090208    0.083406    0.382799    0.090119
# min      0.256570    0.574282   -7.964984    0.006274    1.423287    0.044539
# 25%      0.421306    0.674758   -6.450096    0.174351    2.099125    0.137451
# 50%      0.495954    0.722254   -5.720868    0.218885    2.361532    0.194052
# 75%      0.587562    0.761881   -5.046192    0.279234    2.636456    0.252980
# max      0.685151    0.825288   -2.434031    0.450493    3.671155    0.527367
#
# [8 rows x 23 columns]

# %%
df = df.drop('name', axis=1)

train_df, test_df = train_test_split(df, 
                                     test_size=0.2, 
                                     random_state=SEED)
train_df, val_df = train_test_split(train_df,
                                    test_size=0.2,
                                    random_state=SEED)


X_train = train_df.drop('status', axis=1).values.astype('float32')
y_train = train_df['status'].values.astype('int32')
X_val = val_df.drop('status', axis=1).values.astype('float32')
y_val = val_df['status'].values.astype('int32')
X_test = test_df.drop('status', axis=1).values.astype('float32')
y_test = test_df['status'].values.astype('int32')

mmsc = MinMaxScaler()
X_train = mmsc.fit_transform(X_train) 
X_val = mmsc.transform(X_val)
X_test = mmsc.transform(X_test)

y_train = to_categorical(y_train)
y_val = to_categorical(y_val)
y_test = to_categorical(y_test)

# %% [markdown]
# # Build the model

# %%
shape = X_train.shape[1]
num_classes = y_train.shape[1]

model = Sequential()
model.add(Input((shape,)))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))
opt = tfa.optimizers.RectifiedAdam()
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               2944
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 64)                8256
#
#  dense_3 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 27842 (108.76 KB)
# Trainable params: 27842 (108.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
es_callback = tf.keras.callbacks.EarlyStopping(patience=30, verbose=1, restore_best_weights=True)
history = model.fit(X_train, y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, 
                    validation_data=(X_val, y_val), callbacks=[es_callback])
# Out:
# Epoch 1/300
# 4/4 [==============================] - 0s 32ms/step - loss: 0.6498 - accuracy: 0.7419 - val_loss: 0.6633 - val_accuracy: 0.7188
# Epoch 2/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6483 - accuracy: 0.7419 - val_loss: 0.6608 - val_accuracy: 0.7188
# Epoch 3/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6443 - accuracy: 0.7419 - val_loss: 0.6564 - val_accuracy: 0.7188
# Epoch 4/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.6381 - accuracy: 0.7419 - val_loss: 0.6509 - val_accuracy: 0.7188
# Epoch 5/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6311 - accuracy: 0.7419 - val_loss: 0.6444 - val_accuracy: 0.7188
# Epoch 6/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6231 - accuracy: 0.7419 - val_loss: 0.6373 - val_accuracy: 0.7188
# Epoch 7/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.6146 - accuracy: 0.7419 - val_loss: 0.6300 - val_accuracy: 0.7188
# Epoch 8/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6044 - accuracy: 0.7419 - val_loss: 0.6225 - val_accuracy: 0.7188
# Epoch 9/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5953 - accuracy: 0.7419 - val_loss: 0.6145 - val_accuracy: 0.7188
# Epoch 10/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5848 - accuracy: 0.7419 - val_loss: 0.6060 - val_accuracy: 0.7188
# Epoch 11/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.5732 - accuracy: 0.7419 - val_loss: 0.5970 - val_accuracy: 0.7188
# Epoch 12/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1615 - accuracy: 0.9274 - val_loss: 0.2784 - val_accuracy: 0.8750
# Epoch 73/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1505 - accuracy: 0.9355 - val_loss: 0.2792 - val_accuracy: 0.8750
# Epoch 74/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1539 - accuracy: 0.9194 - val_loss: 0.2809 - val_accuracy: 0.8438
# Epoch 75/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1491 - accuracy: 0.9194 - val_loss: 0.2666 - val_accuracy: 0.8750
# Epoch 76/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1455 - accuracy: 0.9355 - val_loss: 0.2633 - val_accuracy: 0.8750
# Epoch 77/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1393 - accuracy: 0.9355 - val_loss: 0.2652 - val_accuracy: 0.8438
# Epoch 78/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1369 - accuracy: 0.9516 - val_loss: 0.2640 - val_accuracy: 0.8438
# Epoch 79/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1322 - accuracy: 0.9516 - val_loss: 0.2537 - val_accuracy: 0.8750
# Epoch 80/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1327 - accuracy: 0.9435 - val_loss: 0.2508 - val_accuracy: 0.8750
# Epoch 81/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1285 - accuracy: 0.9435 - val_loss: 0.2463 - val_accuracy: 0.8750
# Epoch 82/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1222 - accuracy: 0.9435 - val_loss: 0.2503 - val_accuracy: 0.8750
# Epoch 83/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1259 - accuracy: 0.9516 - val_loss: 0.2551 - val_accuracy: 0.8438
# Epoch 84/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.1222 - accuracy: 0.9435 - val_loss: 0.2373 - val_accuracy: 0.8750
# Epoch 85/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1178 - accuracy: 0.9516 - val_loss: 0.2330 - val_accuracy: 0.8438
# Epoch 86/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1133 - accuracy: 0.9597 - val_loss: 0.2383 - val_accuracy: 0.8750
# Epoch 87/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1126 - accuracy: 0.9597 - val_loss: 0.2344 - val_accuracy: 0.8750
# Epoch 88/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1069 - accuracy: 0.9597 - val_loss: 0.2243 - val_accuracy: 0.8438
# Epoch 89/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1067 - accuracy: 0.9597 - val_loss: 0.2220 - val_accuracy: 0.8438
# Epoch 90/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1029 - accuracy: 0.9677 - val_loss: 0.2235 - val_accuracy: 0.8750
# Epoch 91/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1004 - accuracy: 0.9597 - val_loss: 0.2234 - val_accuracy: 0.8750
# Epoch 92/300
# 4/4 [==============================] - 0s 2ms/step - loss: 0.0990 - accuracy: 0.9597 - val_loss: 0.2148 - val_accuracy: 0.9062
# Epoch 93/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0968 - accuracy: 0.9597 - val_loss: 0.2144 - val_accuracy: 0.9062
# Epoch 94/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0959 - accuracy: 0.9597 - val_loss: 0.2138 - val_accuracy: 0.8750
# Epoch 95/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0916 - accuracy: 0.9677 - val_loss: 0.2049 - val_accuracy: 0.9062
# Epoch 96/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0911 - accuracy: 0.9677 - val_loss: 0.2010 - val_accuracy: 0.9062
# Epoch 97/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0875 - accuracy: 0.9677 - val_loss: 0.2021 - val_accuracy: 0.9062
# Epoch 98/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0864 - accuracy: 0.9677 - val_loss: 0.1988 - val_accuracy: 0.9062
# Epoch 99/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0828 - accuracy: 0.9758 - val_loss: 0.1940 - val_accuracy: 0.9062
# Epoch 100/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0818 - accuracy: 0.9758 - val_loss: 0.1911 - val_accuracy: 0.9062
# Epoch 101/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0814 - accuracy: 0.9677 - val_loss: 0.1893 - val_accuracy: 0.9062
# Epoch 102/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0776 - accuracy: 0.9758 - val_loss: 0.1873 - val_accuracy: 0.9062
# Epoch 103/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.
300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0159 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9688
# Epoch 167/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0169 - accuracy: 1.0000 - val_loss: 0.0885 - val_accuracy: 0.9375
# Epoch 168/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0151 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9688
# Epoch 169/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0155 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9688
# Epoch 170/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0160 - accuracy: 1.0000 - val_loss: 0.0898 - val_accuracy: 0.9375
# Epoch 171/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0144 - accuracy: 1.0000 - val_loss: 0.0955 - val_accuracy: 0.9688
# Epoch 172/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.0931 - val_accuracy: 0.9375
# Epoch 173/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 1.0000 - val_loss: 0.0894 - val_accuracy: 0.9375
# Epoch 174/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0133 - accuracy: 1.0000 - val_loss: 0.0918 - val_accuracy: 0.9375
# Epoch 175/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9375
# Epoch 176/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0123 - accuracy: 1.0000 - val_loss: 0.0967 - val_accuracy: 0.9688
# Epoch 177/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0970 - val_accuracy: 0.9375
# Epoch 178/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0122 - accuracy: 1.0000 - val_loss: 0.0919 - val_accuracy: 0.9375
# Epoch 179/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.0881 - val_accuracy: 0.9375
# Epoch 180/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.1100 - val_accuracy: 0.9688
# Epoch 181/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0156 - accuracy: 0.9919 - val_loss: 0.0988 - val_accuracy: 0.9688
# Epoch 182/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9375
# Epoch 183/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0940 - val_accuracy: 0.9375
# Epoch 184/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9375
# Epoch 185/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9375
# Epoch 186/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0901 - val_accuracy: 0.9375
# Epoch 187/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0096 - accuracy: 1.0000 - val_loss: 0.0906 - val_accuracy: 0.9375
# Epoch 188/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0907 - val_accuracy: 0.9375
# Epoch 189/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.0871 - val_accuracy: 0.9375
# Epoch 190/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9688
# Epoch 191/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0104 - accuracy: 1.0000 - val_loss: 0.1006 - val_accuracy: 0.9688
# Epoch 192/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0095 - accuracy: 1.0000 - val_loss: 0.0889 - val_accuracy: 0.9375
# Epoch 193/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0094 - accuracy: 1.0000 - val_loss: 0.0883 - val_accuracy: 0.9375
# Epoch 194/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.0900 - val_accuracy: 0.9375
# Epoch 195/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0890 - val_accuracy: 0.9375
# Epoch 196/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 1.0000 - val_loss: 0.0891 - val_accuracy: 0.9375
# Epoch 197/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0884 - val_accuracy: 0.9375
# Epoch 198/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0078 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9375
# Epoch 199/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.0882 - val_accuracy: 0.9375
# Epoch 200/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 1.0000 - val_loss: 0.0937 - val_accuracy: 0.9375
# Epoch 201/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 1.0000 - val_loss: 0.0925 - val_accuracy: 0.9375
# Epoch 202/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0897 - val_accuracy: 0.9375
# Epoch 203/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.0904 - val_accuracy: 0.9375
# Epoch 204/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0916 - val_accuracy: 0.9375
# Epoch 205/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0064 - accuracy: 1.0000 - val_loss: 0.0912 - val_accuracy: 0.9375
# Epoch 206/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.0888 - val_accuracy: 0.9375
# Epoch 207/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0876 - val_accuracy: 0.9375
# Epoch 208/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0952 - val_accuracy: 0.9375
# Epoch 209/300
# 4/4 [==============================] - 0s 7ms/step - loss: 0.0066 - accuracy: 1.0000 - val_loss: 0.0947 - val_accuracy: 0.9375
# Epoch 210/300
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9375
# Epoch 211/300
# 4/4 [==============================] - 0s 6ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.0905 - val_accuracy: 0.9375
# Epoch 212/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0057 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9375
# Epoch 213/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0908 - val_accuracy: 0.9375
# Epoch 214/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.0939 - val_accuracy: 0.9375
# Epoch 215/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9375
# Epoch 216/300
# 4/4 [==============================] - 0s 8ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 0.9375
# Epoch 217/300
# 4/4 [==============================] - 0s 4ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0917 - val_accuracy: 0.9375
# Epoch 218/300
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.0909 - val_accuracy: 0.9375
# Epoch 219/300
# 1/4 [======>.......................] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 189.
# 4/4 [==============================] - 0s 5ms/step - loss: 0.0048 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9375
# Epoch 219: early stopping

# %%
pd.DataFrame(history.history)[['accuracy', 'val_accuracy']].plot()
pd.DataFrame(history.history)[['loss', 'val_loss']].plot()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 0s/step - loss: 0.2696 - accuracy: 0.9487
# [0.2695707678794861, 0.9487179517745972]

# %% [markdown]
# # Using RF

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix,accuracy_score, classification_report

from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb

import warnings
warnings.filterwarnings('ignore')

# %%
#  let’s read the data into a DataFrame 

#Read the data
df=pd.read_csv('D:/팀 프로젝트/parkinsons.data')
print(df.shape,'\n')
df.head()
# Out:
# (195, 24)
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0      0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1      0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2      0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3      0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4      0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
#
#     spread2        D2       PPE
# 0  0.266482  2.301442  0.284654
# 1  0.335590  2.486855  0.368674
# 2  0.311173  2.342259  0.332634
# 3  0.334147  2.405554  0.368975
# 4  0.234513  2.332180  0.410335
#
# [5 rows x 24 columns]

# %%
print("Original shape of data: ", df.shape)
x = df.drop(['status','name'], axis=1)
print("Featues shape:", x.shape)
y = df.status
print("Target shape: ", y.shape)
# Out:
# Original shape of data:  (195, 24)
# Featues shape: (195, 22)
# Target shape:  (195,)

# %%
scaler = MinMaxScaler((-1, 1))

# fits the data normally 
X = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(X, y, test_size=0.2)

# %%
clf = LogisticRegression()

#Train Model
clf.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
# Prediction on Test and Train Set 
pred_logistic_test = clf.predict(x_test)
pred_logistic_train = clf.predict(x_train)

# %%
print("Training Accuracy: ", accuracy_score(y_train, pred_logistic_train))
print("Test Accuracy: ", accuracy_score(y_test, pred_logistic_test))
# Out:
# Training Accuracy:  0.8589743589743589
# Test Accuracy:  0.8974358974358975

# %%
print("Confusion Matrix: ")
cf_matrix=confusion_matrix(y_test, pred_logistic_test)

print("\nClassification Report:")
print(classification_report(y_test, pred_logistic_test))


import seaborn as sns
sns.heatmap(cf_matrix, annot=True)
# Out:
# Confusion Matrix:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.43      0.60         7
#            1       0.89      1.00      0.94        32
#
#     accuracy                           0.90        39
#    macro avg       0.94      0.71      0.77        39
# weighted avg       0.91      0.90      0.88        39
# <Axes: >

# %%
dt = DecisionTreeClassifier()

# Train model 
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt_test = dt.predict(x_test)
pred_dt_train = dt.predict(x_train)

# %%
print("Training Accuracy: ", accuracy_score(y_train, pred_dt_train))
print("Test Accuracy: ", accuracy_score(y_test, pred_dt_test))
# Out:
# Training Accuracy:  1.0
# Test Accuracy:  0.9230769230769231

# %%
print("Confusion Matrix: ")
cf_matrix=confusion_matrix(y_test, pred_dt_test)

print("\nClassification Report:")
print(classification_report(y_test, pred_dt_test))


import seaborn as sns
sns.heatmap(cf_matrix, annot=True)
# Out:
# Confusion Matrix:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.92        39
#    macro avg       0.89      0.84      0.86        39
# weighted avg       0.92      0.92      0.92        39
# <Axes: >

# %%
print("Confusion Matrix: ")
print(confusion_matrix(y_test, pred_dt_test))

print("\nClassification Report:")
print(classification_report(y_test, pred_dt_test))
# Out:
# Confusion Matrix:
# [[ 5  2]
#  [ 1 31]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.71      0.77         7
#            1       0.94      0.97      0.95        32
#
#     accuracy                           0.92        39
#    macro avg       0.89      0.84      0.86        39
# weighted avg       0.92      0.92      0.92        39

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
train_pred_rf = rf.predict(x_train)
pred_rf = rf.predict(x_test)

# %%
print("Training Accuracy: ",accuracy_score(y_train, train_pred_rf))
print("Test Accuracy: ",accuracy_score(y_test, pred_rf))
# Out:
# Training Accuracy:  1.0
# Test Accuracy:  0.9487179487179487

# %%
print("Confusion Matrix: ")
cf_matrix=confusion_matrix(y_test, pred_rf)

print("\nClassification Report:")
print(classification_report(y_test, pred_rf))
# Out:
# Confusion Matrix:
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       0.94      1.00      0.97        32
#
#     accuracy                           0.95        39
#    macro avg       0.97      0.86      0.90        39
# weighted avg       0.95      0.95      0.95        39

# %%
import seaborn as sns
sns.heatmap(cf_matrix, annot=True)
# Out:
# <AxesSubplot:>
